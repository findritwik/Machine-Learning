# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('/content/orders.csv')
time = pd.read_csv('/content/messages.csv')

# %%
date
# Out:
#            date  product_id  city_id  orders
# 0    2019-12-10        5628       25       3
# 1    2018-08-15        3646       14     157
# 2    2018-10-23        1859       25       1
# 3    2019-08-17        7292       25       1
# 4    2019-01-06        4344       25       3
# ..          ...         ...      ...     ...
# 995  2018-10-08         255       13       1
# 996  2018-12-06        5521        7       1
# 997  2019-05-07         487       26      14
# 998  2019-03-03        1503       21       2
# 999  2019-10-15        6371        7      22
#
# [1000 rows x 4 columns]

# %%
date['date'] = pd.to_datetime(date['date'])

# %%
date
# Out:
#           date  product_id  city_id  orders
# 0   2019-12-10        5628       25       3
# 1   2018-08-15        3646       14     157
# 2   2018-10-23        1859       25       1
# 3   2019-08-17        7292       25       1
# 4   2019-01-06        4344       25       3
# ..         ...         ...      ...     ...
# 995 2018-10-08         255       13       1
# 996 2018-12-06        5521        7       1
# 997 2019-05-07         487       26      14
# 998 2019-03-03        1503       21       2
# 999 2019-10-15        6371        7      22
#
# [1000 rows x 4 columns]

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
date
# Out:
#           date  product_id  city_id  orders
# 0   2019-12-10        5628       25       3
# 1   2018-08-15        3646       14     157
# 2   2018-10-23        1859       25       1
# 3   2019-08-17        7292       25       1
# 4   2019-01-06        4344       25       3
# ..         ...         ...      ...     ...
# 995 2018-10-08         255       13       1
# 996 2018-12-06        5521        7       1
# 997 2019-05-07         487       26      14
# 998 2019-03-03        1503       21       2
# 999 2019-10-15        6371        7      22
#
# [1000 rows x 4 columns]

# %%
date['date_year'] = date['date'].dt.year

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year
# 0   2019-12-10        5628       25       3       2019
# 1   2018-08-15        3646       14     157       2018
# 2   2018-10-23        1859       25       1       2018
# 3   2019-08-17        7292       25       1       2019
# 4   2019-01-06        4344       25       3       2019
# ..         ...         ...      ...     ...        ...
# 995 2018-10-08         255       13       1       2018
# 996 2018-12-06        5521        7       1       2018
# 997 2019-05-07         487       26      14       2019
# 998 2019-03-03        1503       21       2       2019
# 999 2019-10-15        6371        7      22       2019
#
# [1000 rows x 5 columns]

# %%
date['date_month'] = date['date'].dt.month

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month
# 0   2019-12-10        5628       25       3       2019          12
# 1   2018-08-15        3646       14     157       2018           8
# 2   2018-10-23        1859       25       1       2018          10
# 3   2019-08-17        7292       25       1       2019           8
# 4   2019-01-06        4344       25       3       2019           1
# ..         ...         ...      ...     ...        ...         ...
# 995 2018-10-08         255       13       1       2018          10
# 996 2018-12-06        5521        7       1       2018          12
# 997 2019-05-07         487       26      14       2019           5
# 998 2019-03-03        1503       21       2       2019           3
# 999 2019-10-15        6371        7      22       2019          10
#
# [1000 rows x 6 columns]

# %%
date['month_name'] = date['date'].dt.month_name()

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month month_name
# 0   2019-12-10        5628       25       3       2019          12   December
# 1   2018-08-15        3646       14     157       2018           8     August
# 2   2018-10-23        1859       25       1       2018          10    October
# 3   2019-08-17        7292       25       1       2019           8     August
# 4   2019-01-06        4344       25       3       2019           1    January
# ..         ...         ...      ...     ...        ...         ...        ...
# 995 2018-10-08         255       13       1       2018          10    October
# 996 2018-12-06        5521        7       1       2018          12   December
# 997 2019-05-07         487       26      14       2019           5        May
# 998 2019-03-03        1503       21       2       2019           3      March
# 999 2019-10-15        6371        7      22       2019          10    October
#
# [1000 rows x 7 columns]

# %%
date['day'] = date['date'].dt.day

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month month_name  \
# 0   2019-12-10        5628       25       3       2019          12   December
# 1   2018-08-15        3646       14     157       2018           8     August
# 2   2018-10-23        1859       25       1       2018          10    October
# 3   2019-08-17        7292       25       1       2019           8     August
# 4   2019-01-06        4344       25       3       2019           1    January
# ..         ...         ...      ...     ...        ...         ...        ...
# 995 2018-10-08         255       13       1       2018          10    October
# 996 2018-12-06        5521        7       1       2018          12   December
# 997 2019-05-07         487       26      14       2019           5        May
# 998 2019-03-03        1503       21       2       2019           3      March
# 999 2019-10-15        6371        7      22       2019          10    October
#
#      day
# 0     10
# 1     15
# ...

# %%
date['dayofweek'] = date['date'].dt.dayofweek

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month month_name  \
# 0   2019-12-10        5628       25       3       2019          12   December
# 1   2018-08-15        3646       14     157       2018           8     August
# 2   2018-10-23        1859       25       1       2018          10    October
# 3   2019-08-17        7292       25       1       2019           8     August
# 4   2019-01-06        4344       25       3       2019           1    January
# ..         ...         ...      ...     ...        ...         ...        ...
# 995 2018-10-08         255       13       1       2018          10    October
# 996 2018-12-06        5521        7       1       2018          12   December
# 997 2019-05-07         487       26      14       2019           5        May
# 998 2019-03-03        1503       21       2       2019           3      March
# 999 2019-10-15        6371        7      22       2019          10    October
#
#      day  dayofweek
# ...

# %%
date['day_name'] = date['date'].dt.day_name()

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month month_name  \
# 0   2019-12-10        5628       25       3       2019          12   December
# 1   2018-08-15        3646       14     157       2018           8     August
# 2   2018-10-23        1859       25       1       2018          10    October
# 3   2019-08-17        7292       25       1       2019           8     August
# 4   2019-01-06        4344       25       3       2019           1    January
# ..         ...         ...      ...     ...        ...         ...        ...
# 995 2018-10-08         255       13       1       2018          10    October
# 996 2018-12-06        5521        7       1       2018          12   December
# 997 2019-05-07         487       26      14       2019           5        May
# 998 2019-03-03        1503       21       2       2019           3      March
# 999 2019-10-15        6371        7      22       2019          10    October
#
#      day  dayofweek   day_name
# ...

# %%
date['date_weekend'] = np.where(date['day_name'].isin(['Sunday','Saturday']),1,0)

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month month_name  \
# 0   2019-12-10        5628       25       3       2019          12   December
# 1   2018-08-15        3646       14     157       2018           8     August
# 2   2018-10-23        1859       25       1       2018          10    October
# 3   2019-08-17        7292       25       1       2019           8     August
# 4   2019-01-06        4344       25       3       2019           1    January
# ..         ...         ...      ...     ...        ...         ...        ...
# 995 2018-10-08         255       13       1       2018          10    October
# 996 2018-12-06        5521        7       1       2018          12   December
# 997 2019-05-07         487       26      14       2019           5        May
# 998 2019-03-03        1503       21       2       2019           3      March
# 999 2019-10-15        6371        7      22       2019          10    October
#
# ...

# %%
date.drop(columns=['product_id','city_id','orders'])
# Out:
#           date  date_year  date_month month_name  day  dayofweek   day_name  \
# 0   2019-12-10       2019          12   December   10          1    Tuesday
# 1   2018-08-15       2018           8     August   15          2  Wednesday
# 2   2018-10-23       2018          10    October   23          1    Tuesday
# 3   2019-08-17       2019           8     August   17          5   Saturday
# 4   2019-01-06       2019           1    January    6          6     Sunday
# ..         ...        ...         ...        ...  ...        ...        ...
# 995 2018-10-08       2018          10    October    8          0     Monday
# 996 2018-12-06       2018          12   December    6          3   Thursday
# 997 2019-05-07       2019           5        May    7          1    Tuesday
# 998 2019-03-03       2019           3      March    3          6     Sunday
# 999 2019-10-15       2019          10    October   15          1    Tuesday
#
#      date_weekend
# 0               0
# ...

# %%
date['quaters'] = date['date'].dt.quarter

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month month_name  \
# 0   2019-12-10        5628       25       3       2019          12   December
# 1   2018-08-15        3646       14     157       2018           8     August
# 2   2018-10-23        1859       25       1       2018          10    October
# 3   2019-08-17        7292       25       1       2019           8     August
# 4   2019-01-06        4344       25       3       2019           1    January
# ..         ...         ...      ...     ...        ...         ...        ...
# 995 2018-10-08         255       13       1       2018          10    October
# 996 2018-12-06        5521        7       1       2018          12   December
# 997 2019-05-07         487       26      14       2019           5        May
# 998 2019-03-03        1503       21       2       2019           3      March
# 999 2019-10-15        6371        7      22       2019          10    October
#
# ...

# %%
date.drop(columns=['product_id','city_id','orders'])
# Out:
#           date  date_year  date_month month_name  day  dayofweek   day_name  \
# 0   2019-12-10       2019          12   December   10          1    Tuesday
# 1   2018-08-15       2018           8     August   15          2  Wednesday
# 2   2018-10-23       2018          10    October   23          1    Tuesday
# 3   2019-08-17       2019           8     August   17          5   Saturday
# 4   2019-01-06       2019           1    January    6          6     Sunday
# ..         ...        ...         ...        ...  ...        ...        ...
# 995 2018-10-08       2018          10    October    8          0     Monday
# 996 2018-12-06       2018          12   December    6          3   Thursday
# 997 2019-05-07       2019           5        May    7          1    Tuesday
# 998 2019-03-03       2019           3      March    3          6     Sunday
# 999 2019-10-15       2019          10    October   15          1    Tuesday
#
#      date_weekend  quaters
# 0               0        4
# ...

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month month_name  \
# 0   2019-12-10        5628       25       3       2019          12   December
# 1   2018-08-15        3646       14     157       2018           8     August
# 2   2018-10-23        1859       25       1       2018          10    October
# 3   2019-08-17        7292       25       1       2019           8     August
# 4   2019-01-06        4344       25       3       2019           1    January
# ..         ...         ...      ...     ...        ...         ...        ...
# 995 2018-10-08         255       13       1       2018          10    October
# 996 2018-12-06        5521        7       1       2018          12   December
# 997 2019-05-07         487       26      14       2019           5        May
# 998 2019-03-03        1503       21       2       2019           3      March
# 999 2019-10-15        6371        7      22       2019          10    October
#
# ...

# %%
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month month_name  day  dayofweek   day_name  \
# 0 2019-12-10       2019          12   December   10          1    Tuesday
# 1 2018-08-15       2018           8     August   15          2  Wednesday
# 2 2018-10-23       2018          10    October   23          1    Tuesday
# 3 2019-08-17       2019           8     August   17          5   Saturday
# 4 2019-01-06       2019           1    January    6          6     Sunday
#
#    date_weekend  quaters
# 0             0        4
# 1             0        3
# 2             0        4
# 3             1        3
# 4             1        1

# %%
date['semester'] = np.where(date['quaters'].isin([1,2]),1,2)


date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month month_name  day  dayofweek   day_name  \
# 0 2019-12-10       2019          12   December   10          1    Tuesday
# 1 2018-08-15       2018           8     August   15          2  Wednesday
# 2 2018-10-23       2018          10    October   23          1    Tuesday
# 3 2019-08-17       2019           8     August   17          5   Saturday
# 4 2019-01-06       2019           1    January    6          6     Sunday
#
#    date_weekend  quaters  semester
# 0             0        4         2
# 1             0        3         2
# 2             0        4         2
# 3             1        3         2
# 4             1        1         1

# %%
time
# Out:
#                     date                                                msg
# 0    2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1    2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2    2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3    2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4    2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                   ...                                                ...
# 995  2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996  2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997  2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998  2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999  2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
# [1000 rows x 2 columns]

# %%
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time
# Out:
#                    date                                                msg
# 0   2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1   2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2   2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3   2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4   2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                  ...                                                ...
# 995 2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996 2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997 2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998 2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999 2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
# [1000 rows x 2 columns]

# %%
time['date_hour'] = time['date'].dt.hour
time['date_minute'] = time['date'].dt.minute
time['date_second'] = time['date'].dt.second

# %%
time.drop(columns=['msg'])
# Out:
#                    date  date_hour  date_minute  date_second
# 0   2013-12-15 00:50:00          0           50            0
# 1   2014-04-29 23:40:00         23           40            0
# 2   2012-12-30 00:21:00          0           21            0
# 3   2014-11-28 00:31:00          0           31            0
# 4   2013-10-26 23:11:00         23           11            0
# ..                  ...        ...          ...          ...
# 995 2012-03-16 00:50:00          0           50            0
# 996 2014-01-23 23:14:00         23           14            0
# 997 2012-10-15 23:37:00         23           37            0
# 998 2012-06-21 23:34:00         23           34            0
# 999 2014-06-19 23:25:00         23           25            0
#
# [1000 rows x 4 columns]

# %%
time['date_time'] = time['date'].dt.time
time.drop(columns=['msg'],inplace=True)

# %%
time
# Out:
#                    date  date_hour  date_minute  date_second date_time
# 0   2013-12-15 00:50:00          0           50            0  00:50:00
# 1   2014-04-29 23:40:00         23           40            0  23:40:00
# 2   2012-12-30 00:21:00          0           21            0  00:21:00
# 3   2014-11-28 00:31:00          0           31            0  00:31:00
# 4   2013-10-26 23:11:00         23           11            0  23:11:00
# ..                  ...        ...          ...          ...       ...
# 995 2012-03-16 00:50:00          0           50            0  00:50:00
# 996 2014-01-23 23:14:00         23           14            0  23:14:00
# 997 2012-10-15 23:37:00         23           37            0  23:37:00
# 998 2012-06-21 23:34:00         23           34            0  23:34:00
# 999 2014-06-19 23:25:00         23           25            0  23:25:00
#
# [1000 rows x 5 columns]

# %%
import datetime

today = datetime.datetime.today()

today
# Out:
# datetime.datetime(2025, 6, 27, 13, 42, 51, 565511)

# %%
today - date['date']
# Out:
# 0     2026 days 13:42:51.565511
# 1     2508 days 13:42:51.565511
# 2     2439 days 13:42:51.565511
# 3     2141 days 13:42:51.565511
# 4     2364 days 13:42:51.565511
#                  ...
# 995   2454 days 13:42:51.565511
# 996   2395 days 13:42:51.565511
# 997   2243 days 13:42:51.565511
# 998   2308 days 13:42:51.565511
# 999   2082 days 13:42:51.565511
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
date['date']
# Out:
# 0     2019-12-10
# 1     2018-08-15
# 2     2018-10-23
# 3     2019-08-17
# 4     2019-01-06
#          ...
# 995   2018-10-08
# 996   2018-12-06
# 997   2019-05-07
# 998   2019-03-03
# 999   2019-10-15
# Name: date, Length: 1000, dtype: datetime64[ns]

# %%
time
# Out:
#                    date  date_hour  date_minute  date_second date_time
# 0   2013-12-15 00:50:00          0           50            0  00:50:00
# 1   2014-04-29 23:40:00         23           40            0  23:40:00
# 2   2012-12-30 00:21:00          0           21            0  00:21:00
# 3   2014-11-28 00:31:00          0           31            0  00:31:00
# 4   2013-10-26 23:11:00         23           11            0  23:11:00
# ..                  ...        ...          ...          ...       ...
# 995 2012-03-16 00:50:00          0           50            0  00:50:00
# 996 2014-01-23 23:14:00         23           14            0  23:14:00
# 997 2012-10-15 23:37:00         23           37            0  23:37:00
# 998 2012-06-21 23:34:00         23           34            0  23:34:00
# 999 2014-06-19 23:25:00         23           25            0  23:25:00
#
# [1000 rows x 5 columns]

# %%
(today - time['date'])/np.timedelta64(1,'m')
# Out:
# 0      6.066053e+06
# 1      5.870283e+06
# 2      6.570082e+06
# 3      5.564952e+06
# 4      6.136712e+06
#            ...
# 995    6.986213e+06
# 996    6.008549e+06
# 997    6.678126e+06
# 998    6.845169e+06
# 999    5.796858e+06
# Name: date, Length: 1000, dtype: float64

# %%
(today - time['date'])/np.timedelta64(1,'s')
# Out:
# 0      3.639632e+08
# 1      3.522170e+08
# 2      3.942049e+08
# 3      3.338971e+08
# 4      3.682027e+08
#            ...
# 995    4.191728e+08
# 996    3.605129e+08
# 997    4.006876e+08
# 998    4.107101e+08
# 999    3.478115e+08
# Name: date, Length: 1000, dtype: float64

# %%
(today - time['date'])/np.timedelta64(1,'h')
# Out:
# 0      101100.880990
# 1       97838.047657
# 2      109501.364324
# 3       92749.197657
# 4      102278.530990
#            ...
# 995    116436.880990
# 996    100142.480990
# 997    111302.097657
# 998    114086.147657
# 999     96614.297657
# Name: date, Length: 1000, dtype: float64
